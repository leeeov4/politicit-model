# %%
# !git clone https://github.com/leeeov4/politicit-model.git
# !pip install -r politicit-model/requirements.txt
# Out:
# Cloning into 'politicit-model'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 24 (delta 5), reused 23 (delta 4), pack-reused 0 (from 0)
# Receiving objects: 100% (24/24), 4.39 MiB | 11.83 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# Requirement already satisfied: transformers>=4.36.0 in /usr/local/lib/python3.11/dist-packages (from -r politicit-model/requirements.txt (line 1)) (4.52.4)
# Requirement already satisfied: tensorflow>=2.11 in /usr/local/lib/python3.11/dist-packages (from -r politicit-model/requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: huggingface_hub>=0.21.1 in /usr/local/lib/python3.11/dist-packages (from -r politicit-model/requirements.txt (line 3)) (0.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (5.29.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (1.72.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (3.13.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.37.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.1->-r politicit-model/requirements.txt (line 3)) (2025.3.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub>=0.21.1->-r politicit-model/requirements.txt (line 3)) (1.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers>=4.36.0->-r politicit-model/requirements.txt (line 1)) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.11->-r politicit-model/requirements.txt (line 2)) (0.1.2)

# %%
cd politicit-model/
# Out:
# /content/politicit-model

# %%
from politicit_model import PoliticITModel

model = PoliticITModel()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.59k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.18M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/1.11M [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/235k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/3.25k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/494 [00:00<?, ?B/s]
# fingerprint.pb:   0%|          | 0.00/56.0 [00:00<?, ?B/s]
# saved_model.pb:   0%|          | 0.00/18.6M [00:00<?, ?B/s]
# keras_metadata.pb:   0%|          | 0.00/359k [00:00<?, ?B/s]
# variables/variables.data-00000-of-00001:   0%|          | 0.00/1.19G [00:00<?, ?B/s]
# variables.index:   0%|          | 0.00/24.6k [00:00<?, ?B/s]

# %%
#preprocess
from politicit_model.utils import print_prediction

# %%
result = model.predict("Oggi, sabato 31 dicembre, alle ore 9.34, nel Monastero Mater Ecclesiae in Vaticano, il Signore ha chiamato a Sé il Santo Padre Emerito Benedetto XVI.")
print_prediction(result)
# Out:
# 1/1 [==============================] - 10s 10s/step
# Gender:
#   - Male: 33.85%     [===       ]
#   - Female: 66.15%   [======    ]
#
# Political ideology (binary):
#   - Left: 71.65%     [=======   ]
#   - Right: 28.35%   [==        ]
#
# Political ideology (multiclass):
#   - 'Left': 36.18%             [===       ]
#   - 'Right': 29.54%            [==        ]
#   - 'Moderate left': 9.92%   [          ]
#   - 'Moderate right': 24.36%   [==        ]
